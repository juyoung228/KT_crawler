# %%
#!pip install gensim
# Out:
# ...
#   Running setup.py bdist_wheel for smart-open: started
#   Running setup.py bdist_wheel for smart-open: finished with status 'done'
#   Stored in directory: C:\Users\Administrator\AppData\Local\pip\Cache\wheels\b1\9e\7d\bb3d3b55c597e72617140a0638c06382a5f17283881eae163e
#   Running setup.py bdist_wheel for bz2file: started
#   Running setup.py bdist_wheel for bz2file: finished with status 'done'
#   Stored in directory: C:\Users\Administrator\AppData\Local\pip\Cache\wheels\81\75\d6\e1317bf09bf1af5a30befc2a007869fa6e1f516b8f7c591cb9
# Successfully built smart-open bz2file
# ...
#   Found existing installation: numpy 1.11.1
#     Uninstalling numpy-1.11.1:
#       Successfully uninstalled numpy-1.11.1
# ...

# %%
class SentenceReader:

    def __init__(self, filepath):
        self.filepath = filepath

    def __iter__(self):
        for line in codecs.open(self.filepath, encoding='utf-8'):
            yield line.split('\t')

# %%
import gensim
import codecs

sentences_vocab = SentenceReader('./kt_result_morph_sen.txt')
sentences_train = SentenceReader('./kt_result_morph_sen.txt')

model = gensim.models.Word2Vec()
model.build_vocab(sentences_vocab)
model.train(sentences_vocab, total_examples=model.corpus_count, epochs=model.iter)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# (1724246, 2534670)

# %%
model.save('./model')
model = gensim.models.Word2Vec.load('./model')

# %%
model.most_similar('기가지니-NNP', topn=100)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [('실외-NNG', 0.8082280158996582),
#  ('랜카드-NNP', 0.8012979030609131),
#  ('LTE-SL', 0.7992761135101318),
#  ('이벤트-NNG', 0.7978395223617554),
#  ('셋탑박스-NNG', 0.7946438789367676),
#  ('와이파이-NNP', 0.7915657758712769),
#  ('대-EC', 0.7784133553504944),
#  ('셋톱박스-NNP', 0.7749450206756592),
#  ('별도-NNG', 0.772708535194397),
#  ('최저-NNG', 0.7717698812484741),
#  ('공유기-NNP', 0.7704497575759888),
#  ('KT스카이라이프-NNP', 0.766867458820343),
#  ('셋탑-NNG', 0.7662688493728638),
#  ('안테나-NNG', 0.7643885612487793),
#  ('TV-SL', 0.7641342878341675),
#  ('인터넷-NNG', 0.7637431025505066),
#  ('포인트-NNG', 0.7634558081626892),
#  ('비-NNG', 0.763305127620697),
#  ('올-MM', 0.7598528861999512),
#  ('레-NNP', 0.7597756385803223),
#  ('tv-SL', 0.758604884147644),
# ...

# %%
model.most_similar('지니-NNP', topn=20)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [('야-JKV', 0.8515885472297668),
#  ('틀-VV', 0.7791600227355957),
#  ('에다가-JKB', 0.6647107005119324),
#  ('비키-VV', 0.6621626615524292),
#  ('뮤직-NNG', 0.6603741645812988),
#  ('동화책-NNG', 0.6568633317947388),
#  ('노래-NNG', 0.6508559584617615),
#  ('기가-NNB', 0.635289192199707),
#  ('올리-VV', 0.6334241032600403),
#  ('끄-VV', 0.6297959089279175),
#  ('켜-VV', 0.6283665895462036),
#  ('펫-NNP', 0.6227698922157288),
#  ('부르-VV', 0.6138973832130432),
#  ('지니-VV', 0.6035028696060181),
#  ('낮추-VV', 0.6027321219444275),
#  ('꺼지-VV', 0.5997374057769775),
#  ('최신-NNG', 0.5873113870620728),
#  ('열-VV', 0.5871478319168091),
#  ('챙기-VV', 0.5860828161239624),
#  ('카오-NNP', 0.5821139812469482)]

# %%
model.most_similar('기가-NNP', topn=20)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [('콤팩트-NNG', 0.9230393767356873),
#  ('무료-NNG', 0.9209848642349243),
#  ('인터넷-NNG', 0.9107460975646973),
#  ('개월-NNB', 0.9101558923721313),
#  ('와이파이-NNP', 0.8976385593414307),
#  ('무선랜-NNP', 0.8968651294708252),
#  ('storefarm-SL', 0.8943681716918945),
#  ('약정-NNG', 0.8875948190689087),
#  ('kt-SL', 0.8854421377182007),
#  ('대-NNB', 0.8840733766555786),
#  ('카드-NNG', 0.8831911087036133),
#  ('올레TV-NNP', 0.8810508251190186),
#  ('제한-NNG', 0.8796066045761108),
#  ('유무선-NNG', 0.8789808750152588),
#  ('시-XSN', 0.8789281249046326),
#  ('올-NNG', 0.8776160478591919),
#  ('신용카드-NNP', 0.8767035603523254),
#  ('WIFI-SL', 0.875516951084137),
#  ('포인트-NNG', 0.8743035197257996),
#  ('결합-NNG', 0.8742440938949585)]

# %%
model.most_similar('장점-NNG', topn=100)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [('차이점-NNG', 0.9461355209350586),
#  ('특징-NNG', 0.8773437738418579),
#  ('용량-NNG', 0.872067928314209),
#  ('가장-MAG', 0.8646068572998047),
#  ('인공지능-NNP', 0.860693097114563),
#  ('유일-NNG', 0.8567309975624084),
#  ('보니-NNP', 0.8545324802398682),
#  ('보통-NNG', 0.8473470211029053),
#  ('기술력-NNG', 0.8452869653701782),
#  ('대세-NNG', 0.8438447713851929),
#  ('단점-NNG', 0.8421249389648438),
#  ('대기업-NNG', 0.8366267085075378),
#  ('후손-NNG', 0.833113968372345),
#  ('서킷-NNG', 0.8325871825218201),
#  ('뜻-NNG', 0.8301792144775391),
#  ('동계올림픽-NNP', 0.8299462199211121),
#  ('식별-NNG', 0.8292250037193298),
#  ('포토-NNG', 0.8288965225219727),
#  ('음질-NNG', 0.8288108110427856),
#  ('뛰어나-VA', 0.8283671140670776),
#  ('디자인-NNG', 0.827756404876709),
# ...

# %%
model.most_similar('단점-NNG', topn=200)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [('사실-NNG', 0.9072794318199158),
#  ('표현-NNG', 0.9029907584190369),
#  ('세월-NNG', 0.8972376585006714),
#  ('존재-NNG', 0.8967505097389221),
#  ('렌터카-NNG', 0.8894767761230469),
#  ('불안감-NNG', 0.8889685869216919),
#  ('사라지-VV', 0.8870444297790527),
#  ('실물-NNG', 0.8864467740058899),
#  ('기운-NNG', 0.8864262104034424),
#  ('마르-VV', 0.8839495778083801),
#  ('다른-MM', 0.8806523084640503),
#  ('소품-NNG', 0.8777755498886108),
#  ('의문-NNG', 0.8776072859764099),
#  ('벌어지-VV', 0.8775306344032288),
#  ('축복-NNG', 0.8770519495010376),
#  ('행동-NNG', 0.8765000104904175),
#  ('생겨나-VV', 0.8722547888755798),
#  ('단어-NNG', 0.8713111281394958),
#  ('엄청나-VA', 0.8696901798248291),
#  ('놈-NNB', 0.8695343136787415),
#  ('품-VV', 0.8689576983451843),
# ...

# %%
model.most_similar('특징-NNG', topn=100)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [('경쟁-NNG', 0.9433047771453857),
#  ('라인업-NNG', 0.9369566440582275),
#  ('기인-NNG', 0.9339581727981567),
#  ('스펙-NNP', 0.9275231957435608),
#  ('DRX-SL', 0.9263216853141785),
#  ('CPU-SL', 0.9255625605583191),
#  ('액세서리-NNG', 0.9240413904190063),
#  ('용량-NNG', 0.9235957860946655),
#  ('형태-NNG', 0.9234486818313599),
#  ('규격-NNG', 0.9230395555496216),
#  ('국내-NNG', 0.9224216938018799),
#  ('인공지능-NNP', 0.9215567111968994),
#  ('W-SL', 0.9208625555038452),
#  ('본체-NNG', 0.9199780225753784),
#  ('일부-NNG', 0.9186676740646362),
#  ('신제품-NNG', 0.9185429215431213),
#  ('LG-SL', 0.9181723594665527),
#  ('ICT-SL', 0.9181344509124756),
#  ('음향-NNG', 0.9175585508346558),
#  ('정책-NNG', 0.9172425270080566),
#  ('프로세서-NNG', 0.9169886112213135),
# ...
